# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point
from geopy.distance import geodesic
from math import radians, sin, cos, sqrt, atan2
import openpyxl

# %%
tc_harold = gpd.read_file('TC_Harold_2020.geojson')

# %%
tc_harold = gpd.GeoDataFrame(tc_harold, crs="EPSG:4326")  # Assuming WGS84

# %%
# Set CRS to WGS84 (EPSG:4326)
tc_harold.set_crs(epsg=4326, inplace=True)

# Convert to UTM zone 59S (EPSG:32759)
# gdf_utm = tc_harold.to_crs(epsg=32759)
tc_harold = tc_harold.to_crs(epsg=32759)

# %%
tc_harold
# Out:
#         Serial_Num Season Num Basin Sub_basin    Name         ISO_time Nature  \
# 0    2020089S05147   2020  12    SP        EA  HAROLD  3/29/2020 12:00     NR
# 1    2020089S05147   2020  12    SP        EA  HAROLD  3/29/2020 18:00     NR
# 2    2020089S05147   2020  12    SP        EA  HAROLD   3/30/2020 0:00     NR
# 3    2020089S05147   2020  12    SP        EA  HAROLD   3/30/2020 6:00     NR
# 4    2020089S05147   2020  12    SP        EA  HAROLD  3/30/2020 12:00     NR
# ..             ...    ...  ..   ...       ...     ...              ...    ...
# 107
# 108
# 109
# 110
# 111
#
#     Latitude Longitude Mean Wind Speed Mean Central Pressure  \
# 0       -4.9     146.6              15                  1010
# 1       -5.3     147.3              15                  1010
# 2       -5.8     148.2              15                  1010
# 3       -6.4     149.5              15                  1010
# 4       -7.1     150.6              15                  1010
# ..       ...       ...             ...                   ...
# 107
# 108
# 109
# 110
# 111
#
#     Center(s) or Source                          geometry
# 0                   ASW  POINT (-2290192.703 9405158.365)
# 1                   ASW  POINT (-2203387.024 9360154.711)
# 2                   ASW  POINT (-2092516.423 9304572.791)
# 3                   ASW  POINT (-1934317.539 9239768.528)
# 4                   ASW  POINT (-1800627.378 9162886.701)
# ..                  ...                               ...
# 107                                                  None
# 108                                                  None
# 109                                                  None
# 110                                                  None
# 111                                                  None
#
# [112 rows x 14 columns]

# %%
distances = []

# %%
# Calculate distances between each point and the next point
tc_harold['next_geometry'] = tc_harold['geometry'].shift(-1)
tc_harold['distance_to_next'] = tc_harold.apply(
    lambda row: row['geometry'].distance(row['next_geometry']) if pd.notnull(row['next_geometry']) else None,
    axis=1
)

# Drop the next_geometry column for a cleaner output
# gdf.drop(columns=['next_geometry'], inplace=True)

print(tc_harold[['ISO_time', 'Mean Wind Speed', 'geometry', 'distance_to_next']])
# Out:
#             ISO_time Mean Wind Speed                          geometry  \
# 0    3/29/2020 12:00              15  POINT (-2290192.703 9405158.365)
# 1    3/29/2020 18:00              15  POINT (-2203387.024 9360154.711)
# 2     3/30/2020 0:00              15  POINT (-2092516.423 9304572.791)
# 3     3/30/2020 6:00              15  POINT (-1934317.539 9239768.528)
# 4    3/30/2020 12:00              15  POINT (-1800627.378 9162886.701)
# ..               ...             ...                               ...
# 107                                                               None
# 108                                                               None
# 109                                                               None
# 110                                                               None
# 111                                                               None
#
#      distance_to_next
# 0        97778.089519
# 1       124022.740175
# 2       170957.536388
# 3       154220.214410
# 4       162895.681179
# ..                ...
# 107               NaN
# 108               NaN
# 109               NaN
# 110               NaN
# 111               NaN
#
# [112 rows x 4 columns]

# %%
print(tc_harold.columns)
# Out:
# Index(['Serial_Num', 'Season', 'Num', 'Basin', 'Sub_basin', 'Name', 'ISO_time',
#        'Nature', 'Latitude', 'Longitude', 'Mean Wind Speed',
#        'Mean Central Pressure', 'Center(s) or Source', 'geometry',
#        'next_geometry', 'distance_to_next'],
#       dtype='object')

# %%
# Create a GeoDataFrame
tc_harold['timestamp'] = pd.to_datetime(tc_harold['ISO_time'])
tc_harold = gpd.GeoDataFrame(tc_harold, geometry='geometry')

# %%
tc_harold
# Out:
#         Serial_Num Season Num Basin Sub_basin    Name         ISO_time Nature  \
# 0    2020089S05147   2020  12    SP        EA  HAROLD  3/29/2020 12:00     NR
# 1    2020089S05147   2020  12    SP        EA  HAROLD  3/29/2020 18:00     NR
# 2    2020089S05147   2020  12    SP        EA  HAROLD   3/30/2020 0:00     NR
# 3    2020089S05147   2020  12    SP        EA  HAROLD   3/30/2020 6:00     NR
# 4    2020089S05147   2020  12    SP        EA  HAROLD  3/30/2020 12:00     NR
# ..             ...    ...  ..   ...       ...     ...              ...    ...
# 107
# 108
# 109
# 110
# 111
#
#     Latitude Longitude Mean Wind Speed Mean Central Pressure  \
# 0       -4.9     146.6              15                  1010
# 1       -5.3     147.3              15                  1010
# 2       -5.8     148.2              15                  1010
# 3       -6.4     149.5              15                  1010
# 4       -7.1     150.6              15                  1010
# ..       ...       ...             ...                   ...
# 107
# 108
# 109
# 110
# 111
#
#     Center(s) or Source                          geometry  \
# 0                   ASW  POINT (-2290192.703 9405158.365)
# 1                   ASW  POINT (-2203387.024 9360154.711)
# 2                   ASW  POINT (-2092516.423 9304572.791)
# 3                   ASW  POINT (-1934317.539 9239768.528)
# 4                   ASW  POINT (-1800627.378 9162886.701)
# ..                  ...                               ...
# 107                                                  None
# 108                                                  None
# 109                                                  None
# 110                                                  None
# 111                                                  None
#
#                         next_geometry  distance_to_next           timestamp
# 0    POINT (-2203387.024 9360154.711)      97778.089519 2020-03-29 12:00:00
# 1    POINT (-2092516.423 9304572.791)     124022.740175 2020-03-29 18:00:00
# 2    POINT (-1934317.539 9239768.528)     170957.536388 2020-03-30 00:00:00
# 3    POINT (-1800627.378 9162886.701)     154220.214410 2020-03-30 06:00:00
# 4    POINT (-1656307.772 9087342.978)     162895.681179 2020-03-30 12:00:00
# ..                                ...               ...                 ...
# 107                              None               NaN                 NaT
# 108                              None               NaN                 NaT
# 109                              None               NaN                 NaT
# 110                              None               NaN                 NaT
# 111                              None               NaN                 NaT
#
# [112 rows x 17 columns]

# %%
# Convert the 'timestamp' column to datetime format
tc_harold['timestamp'] = pd.to_datetime(tc_harold['timestamp'])

# Calculate the time difference between the current row and the previous row
tc_harold['time_diff'] = tc_harold['timestamp'].diff()

# tc_harold = tc_harold.dropna['time_difference']

# %%
# Convert 'time_diff' to hours as a float
tc_harold['time_diff_hours'] = tc_harold['time_diff'].dt.total_seconds() / 3600

# fill empty values
tc_harold['time_diff_hours'] = tc_harold['time_diff_hours'].fillna(0)

# Optionally, if you need it as an integer (total hours rounded down)
tc_harold['time_diff_hours'] = tc_harold['time_diff_hours'].astype(int)

# %%
tc_harold
# Out:
#         Serial_Num Season Num Basin Sub_basin    Name         ISO_time Nature  \
# 0    2020089S05147   2020  12    SP        EA  HAROLD  3/29/2020 12:00     NR
# 1    2020089S05147   2020  12    SP        EA  HAROLD  3/29/2020 18:00     NR
# 2    2020089S05147   2020  12    SP        EA  HAROLD   3/30/2020 0:00     NR
# 3    2020089S05147   2020  12    SP        EA  HAROLD   3/30/2020 6:00     NR
# 4    2020089S05147   2020  12    SP        EA  HAROLD  3/30/2020 12:00     NR
# ..             ...    ...  ..   ...       ...     ...              ...    ...
# 107
# 108
# 109
# 110
# 111
#
#     Latitude Longitude Mean Wind Speed Mean Central Pressure  \
# 0       -4.9     146.6              15                  1010
# 1       -5.3     147.3              15                  1010
# 2       -5.8     148.2              15                  1010
# 3       -6.4     149.5              15                  1010
# 4       -7.1     150.6              15                  1010
# ..       ...       ...             ...                   ...
# 107
# 108
# 109
# 110
# 111
#
#     Center(s) or Source                          geometry  \
# 0                   ASW  POINT (-2290192.703 9405158.365)
# 1                   ASW  POINT (-2203387.024 9360154.711)
# 2                   ASW  POINT (-2092516.423 9304572.791)
# 3                   ASW  POINT (-1934317.539 9239768.528)
# 4                   ASW  POINT (-1800627.378 9162886.701)
# ..                  ...                               ...
# 107                                                  None
# 108                                                  None
# 109                                                  None
# 110                                                  None
# 111                                                  None
#
#                         next_geometry  distance_to_next           timestamp  \
# 0    POINT (-2203387.024 9360154.711)      97778.089519 2020-03-29 12:00:00
# 1    POINT (-2092516.423 9304572.791)     124022.740175 2020-03-29 18:00:00
# 2    POINT (-1934317.539 9239768.528)     170957.536388 2020-03-30 00:00:00
# 3    POINT (-1800627.378 9162886.701)     154220.214410 2020-03-30 06:00:00
# 4    POINT (-1656307.772 9087342.978)     162895.681179 2020-03-30 12:00:00
# ..                                ...               ...                 ...
# 107                              None               NaN                 NaT
# 108                              None               NaN                 NaT
# 109                              None               NaN                 NaT
# 110                              None               NaN                 NaT
# 111                              None               NaN                 NaT
#
#           time_diff  time_diff_hours
# 0               NaT                0
# 1   0 days 06:00:00                6
# 2   0 days 06:00:00                6
# 3   0 days 06:00:00                6
# 4   0 days 06:00:00                6
# ..              ...              ...
# 107             NaT                0
# 108             NaT                0
# 109             NaT                0
# 110             NaT                0
# 111             NaT                0
#
# [112 rows x 19 columns]

# %%
# Calculate velocity and velocity difference 
tc_harold['velocity'] = tc_harold.apply(
    lambda row: row['distance_to_next'] / row['time_diff_hours'] if row['time_diff_hours'] != 0 else 0,
    axis=1
)

# %%
tc_harold['velocity_diff'] = tc_harold['velocity'].diff()

# %%
# Calculate velocity and velocity difference 
tc_harold['acceleration_ms-1'] = tc_harold.apply(
    lambda row: row['velocity_diff'] / row['time_diff_hours'] if row['time_diff_hours'] != 0 else 0,
    axis=1
)

# %%
tc_harold
# Out:
#         Serial_Num Season Num Basin Sub_basin    Name         ISO_time Nature  \
# 0    2020089S05147   2020  12    SP        EA  HAROLD  3/29/2020 12:00     NR
# 1    2020089S05147   2020  12    SP        EA  HAROLD  3/29/2020 18:00     NR
# 2    2020089S05147   2020  12    SP        EA  HAROLD   3/30/2020 0:00     NR
# 3    2020089S05147   2020  12    SP        EA  HAROLD   3/30/2020 6:00     NR
# 4    2020089S05147   2020  12    SP        EA  HAROLD  3/30/2020 12:00     NR
# ..             ...    ...  ..   ...       ...     ...              ...    ...
# 107
# 108
# 109
# 110
# 111
#
#     Latitude Longitude  ... Center(s) or Source  \
# 0       -4.9     146.6  ...                 ASW
# 1       -5.3     147.3  ...                 ASW
# 2       -5.8     148.2  ...                 ASW
# 3       -6.4     149.5  ...                 ASW
# 4       -7.1     150.6  ...                 ASW
# ..       ...       ...  ...                 ...
# 107                     ...
# 108                     ...
# 109                     ...
# 110                     ...
# 111                     ...
#
#                              geometry                     next_geometry  \
# 0    POINT (-2290192.703 9405158.365)  POINT (-2203387.024 9360154.711)
# 1    POINT (-2203387.024 9360154.711)  POINT (-2092516.423 9304572.791)
# 2    POINT (-2092516.423 9304572.791)  POINT (-1934317.539 9239768.528)
# 3    POINT (-1934317.539 9239768.528)  POINT (-1800627.378 9162886.701)
# 4    POINT (-1800627.378 9162886.701)  POINT (-1656307.772 9087342.978)
# ..                                ...                               ...
# 107                              None                              None
# 108                              None                              None
# 109                              None                              None
# 110                              None                              None
# 111                              None                              None
#
#     distance_to_next           timestamp       time_diff time_diff_hours  \
# 0       97778.089519 2020-03-29 12:00:00             NaT               0
# 1      124022.740175 2020-03-29 18:00:00 0 days 06:00:00               6
# 2      170957.536388 2020-03-30 00:00:00 0 days 06:00:00               6
# 3      154220.214410 2020-03-30 06:00:00 0 days 06:00:00               6
# 4      162895.681179 2020-03-30 12:00:00 0 days 06:00:00               6
# ..               ...                 ...             ...             ...
# 107              NaN                 NaT             NaT               0
# 108              NaN                 NaT             NaT               0
# 109              NaN                 NaT             NaT               0
# 110              NaN                 NaT             NaT               0
# 111              NaN                 NaT             NaT               0
#
#          velocity  velocity_diff  acceleration_ms-1
# 0        0.000000            NaN           0.000000
# 1    20670.456696   20670.456696        3445.076116
# 2    28492.922731    7822.466035        1303.744339
# 3    25703.369068   -2789.553663        -464.925611
# 4    27149.280196    1445.911128         240.985188
# ..            ...            ...                ...
# 107      0.000000       0.000000           0.000000
# 108      0.000000       0.000000           0.000000
# 109      0.000000       0.000000           0.000000
# 110      0.000000       0.000000           0.000000
# 111      0.000000       0.000000           0.000000
#
# [112 rows x 22 columns]

# %%
tc_harold.to_excel('tc_harold.xlsx', sheet_name='Sheet1', index=False)

# %%
print(tc_harold.crs)
# Out:
# EPSG:32759
