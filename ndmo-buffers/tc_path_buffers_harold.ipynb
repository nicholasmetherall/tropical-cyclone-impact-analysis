# %%
import geopandas as gpd

# %%
tc_harold = gpd.read_file("TC_Harold_2020.geojson")

# %%
tc_harold
# Out:
#         Serial_Num Season Num Basin Sub_basin    Name         ISO_time Nature  \
# 0    2020089S05147   2020  12    SP        EA  HAROLD  3/29/2020 12:00     NR
# 1    2020089S05147   2020  12    SP        EA  HAROLD  3/29/2020 18:00     NR
# 2    2020089S05147   2020  12    SP        EA  HAROLD   3/30/2020 0:00     NR
# 3    2020089S05147   2020  12    SP        EA  HAROLD   3/30/2020 6:00     NR
# 4    2020089S05147   2020  12    SP        EA  HAROLD  3/30/2020 12:00     NR
# ..             ...    ...  ..   ...       ...     ...              ...    ...
# 107
# 108
# 109
# 110
# 111
#
#     Latitude Longitude Mean Wind Speed Mean Central Pressure  \
# 0       -4.9     146.6              15                  1010
# 1       -5.3     147.3              15                  1010
# 2       -5.8     148.2              15                  1010
# 3       -6.4     149.5              15                  1010
# 4       -7.1     150.6              15                  1010
# ...

# %%
tc_harold.plot()
# Out:
# <Axes: >

# %%
tc_harold_path = gpd.read_file("TC_Harold_path.geojson")

# %%
tc_harold_path = tc_harold_path.to_crs(3832)
tc_harold_path.plot()
# Out:
# <Axes: >

# %%
tc_harold_path.crs
# Out:
# <Projected CRS: EPSG:3832>
# Name: WGS 84 / PDC Mercator
# Axis Info [cartesian]:
# - E[east]: Easting (metre)
# - N[north]: Northing (metre)
# Area of Use:
# - name: Pacific Ocean - American Samoa, Antarctica, Australia, Brunei Darussalam, Cambodia, Canada, Chile, China, China - Hong Kong, China - Macao, Cook Islands, Ecuador, Fiji, French Polynesia, Guam, Indonesia, Japan, Kiribati, Democratic People's Republic of Korea (North Korea), Republic of Korea (South Korea), Malaysia, Marshall Islands, Federated States of Micronesia, Nauru, New Caledonia, New Zealand, Niue, Norfolk Island, Northern Mariana Islands, Palau, Panama, Papua New Guinea (PNG), Peru, Philippines, Pitcairn, Russian Federation, Samoa, Singapore, Solomon Islands, Taiwan, Thailand, Tokelau, Tonga, Tuvalu, United States (USA), United States Minor Outlying Islands, Vanuatu, Venezuela, Vietnam, Wallis and Futuna.
# - bounds: (98.69, -60.0, -68.0, 66.67)
# Coordinate Operation:
# - name: Pacific Disaster Center Mercator
# ...

# %%
tc_harold_buffer_10m = tc_harold_path.buffer(10000)
tc_harold_buffer_50m = tc_harold_path.buffer(50000)
tc_harold_buffer_100m = tc_harold_path.buffer(100000)

# %%
tc_harold_buffer_10m.to_file("tc_harold_buffer_10km.geojson")
tc_harold_buffer_50m.to_file("tc_harold_buffer_50km.geojson")
tc_harold_buffer_100m.to_file("tc_harold_buffer_100km.geojson")

# %%
tc_harold_path = gpd.read_file("TC_Harold_path.geojson")
tc_harold_path = tc_harold_path.to_crs(3832)
tc_harold_path.plot()
tc_harold_buffer_10m = tc_harold_path.buffer(10000)
tc_harold_buffer_50m = tc_harold_path.buffer(50000)
tc_harold_buffer_100m = tc_harold_path.buffer(100000)
tc_harold_buffer_10m.to_file("tc_harold_buffer_10km.geojson")
tc_harold_buffer_50m.to_file("tc_harold_buffer_50km.geojson")
tc_harold_buffer_100m.to_file("tc_harold_buffer_100km.geojson")

# %%
tc_winston_path = gpd.read_file("TC_Winston_path.geojson")
tc_winston_path = tc_winston_path.to_crs(3832)
tc_winston_path.plot()
tc_winston_buffer_10m = tc_winston_path.buffer(10000)
tc_winston_buffer_50m = tc_winston_path.buffer(50000)
tc_winston_buffer_100m = tc_winston_path.buffer(100000)
tc_winston_buffer_10m.to_file("tc_winston_buffer_10km.geojson")
tc_winston_buffer_50m.to_file("tc_winston_buffer_50km.geojson")
tc_winston_buffer_100m.to_file("tc_winston_buffer_100km.geojson")

# %%
tc_yasa_path = gpd.read_file("TC_Yasa2_path.geojson")
tc_yasa_path = tc_yasa_path.to_crs(3832)
tc_yasa_path.plot()
tc_yasa_buffer_10m = tc_yasa_path.buffer(10000)
tc_yasa_buffer_50m = tc_yasa_path.buffer(50000)
tc_yasa_buffer_100m = tc_yasa_path.buffer(100000)
tc_yasa_buffer_10m.to_file("tc_yasa_buffer_10km.geojson")
tc_yasa_buffer_50m.to_file("tc_yasa_buffer_50km.geojson")
tc_yasa_buffer_100m.to_file("tc_yasa_buffer_100km.geojson")
